# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = pd.read_csv('Household-living-costs-price-indexes-march-2023-quarter-expenditure-weights.csv')

# %%
x.head()
# Out:
#         hlpi_name  year   hlpi nzhec               nzhec_name   nzhec_short  \
# 0  All households  2008  allhh     1                     Food          Food
# 1  All households  2008  allhh   1.1     Fruit and vegetables   Fruit & veg
# 2  All households  2008  allhh   1.2   Meat, poultry and fish          Meat
# 3  All households  2008  allhh   1.3             Grocery food  Grocery food
# 4  All households  2008  allhh   1.4  Non-alcoholic beverages   Soft drinks
#
#       level  nzhec1 nzhec1_name nzhec1_short  weight  exp_pw  eqv_exp_pw
# 0     group       1        Food         Food    18.0   146.4        86.8
# 1  subgroup       1        Food         Food     2.6    21.1        12.5
# 2  subgroup       1        Food         Food     3.1    25.2        14.9
# 3  subgroup       1        Food         Food     7.4    60.2        35.7
# 4  subgroup       1        Food         Food     1.7    13.8         8.2

# %%
# Display the "nzhec_name" column
nzhec_name_column = x['nzhec_name']
nzhec_name_column.head()
# Out:
# 0                       Food
# 1       Fruit and vegetables
# 2     Meat, poultry and fish
# 3               Grocery food
# 4    Non-alcoholic beverages
# Name: nzhec_name, dtype: object

# %%
hlpi_name_column = x['hlpi']
hlpi_name_column.head()
# Out:
# 0    allhh
# 1    allhh
# 2    allhh
# 3    allhh
# 4    allhh
# Name: hlpi, dtype: object

# %%
exp_pw_name_column = x['exp_pw']
exp_pw_name_column.head()
# Out:
# 0    146.4
# 1     21.1
# 2     25.2
# 3     60.2
# 4     13.8
# Name: exp_pw, dtype: float64

# %%
x
# Out:
#            hlpi_name  year   hlpi    nzhec  \
# 0     All households  2008  allhh        1
# 1     All households  2008  allhh      1.1
# 2     All households  2008  allhh      1.2
# 3     All households  2008  allhh      1.3
# 4     All households  2008  allhh      1.4
# ...              ...   ...    ...      ...
# 5917  Superannuitant  2022  super     13.1
# 5918  Superannuitant  2022  super  04.1.01
# 5919  Superannuitant  2022  super  04.4.03
# 5920  Superannuitant  2022  super  04.5.01
# 5921  Superannuitant  2022  super  07.2.02
#
#                               nzhec_name            nzhec_short     level  \
# 0                                   Food                   Food     group
# 1                   Fruit and vegetables            Fruit & veg  subgroup
# 2                 Meat, poultry and fish                   Meat  subgroup
# 3                           Grocery food           Grocery food  subgroup
# ...

# %%
# Remove rows with NaN values
x = x.dropna()
x
# Out:
#            hlpi_name  year   hlpi    nzhec  \
# 0     All households  2008  allhh        1
# 1     All households  2008  allhh      1.1
# 2     All households  2008  allhh      1.2
# 3     All households  2008  allhh      1.3
# 4     All households  2008  allhh      1.4
# ...              ...   ...    ...      ...
# 4237  Superannuitant  2020  super     13.1
# 4238  Superannuitant  2020  super  04.1.01
# 4239  Superannuitant  2020  super  04.4.03
# 4240  Superannuitant  2020  super  04.5.01
# 4241  Superannuitant  2020  super  07.2.02
#
#                               nzhec_name            nzhec_short     level  \
# 0                                   Food                   Food     group
# 1                   Fruit and vegetables            Fruit & veg  subgroup
# 2                 Meat, poultry and fish                   Meat  subgroup
# 3                           Grocery food           Grocery food  subgroup
# ...

# %%
plt.scatter(x.eqv_exp_pw,x.year)
plt.title('Year & Equivalent Expenditure') # Adding a title to the plot
plt.xlabel("Equivalent Expenditure") # Adding the label for the horizontal axis
plt.ylabel("Year") # Adding the label for the vertical axis
plt.show()

# %%
#In Matplotlib we can create a line chart by calling the native .plot() method,
#which is a versatile command, and will take an arbitrary number of arguments:
plt.plot(x.eqv_exp_pw,x.year) # 2 arguments: X and Y points
plt.xlabel("Equvalent Expenditure") # Adding the label for the horizontal axis
plt.ylabel("Year")
plt.show()

# %%
plt.figure(figsize=(12,5)) # 12x5 plot
plt.plot(x.eqv_exp_pw,x.year) # 2 arguments: X and Y points
plt.xlabel("Equvalent Expenditure") # Adding the label for the horizontal axis
plt.ylabel("Year")
plt.show()

# %%
plt.plot(x.eqv_exp_pw,x.year, linestyle='--', marker='o', color='r')
plt.xlabel("Equivalent Expenditure")
plt.ylabel("Year")
plt.show()

# %%
plt.plot(x.eqv_exp_pw,x.year, '--ro')  # ro = red circles
plt.xlabel("Equivalent Expenditure")
plt.ylabel("Year")
plt.show()

# %%
plt.plot(x.eqv_exp_pw,x.year, 'ro') # ro = red circles
plt.show()

# %%
plt.plot(x.eqv_exp_pw,x.year, 'gx') # gx = green
plt.show()

# %%
#Plotting data on multiple consecutive figures can be done by calling the corresponding graphing
#functions and displaying each figure consecutively
plt.plot(x.eqv_exp_pw,x.year, color="r")
plt.show()
plt.plot(x.year,x.eqv_exp_pw)
plt.show()

# %%
#Instead of creating a separate image for points2, it displays both the plots in the same figure
# (both share the same axes)
plt.plot(x.eqv_exp_pw,x.year, color="r",label='Equivalent Expenditure')
plt.plot(x.exp_pw, x.year, label='Expenditure_pw')

# Adding a legend
plt.legend()

plt.show()

# %%
#. Multiple plots in one figure using Matplotlib
#The .subplot() method is used to add multiple plots in one figure. It takes three arguments:

# 1-nrows: number of rows in the figure
# 2-ncols: number of columns in the figure
# 3-index: index of the plot
plt.subplot(1,2,1)  # row, column, index
plt.plot(x.year, x.weight, "go")
plt.title("Year vs Weight")

## plt.subplot(1,2,2) # row, column, index
plt.subplot(1,2,2).label_outer()

plt.plot(x.year, x.nzhec1, "r^")
plt.title("Year vs NZHEC1")

plt.suptitle("Sub Plots") # Add a centered title to the figure.
plt.show()

# %%
#2 rows and 1 column
plt.subplot(2,1,1) # row, column, index
plt.plot(x.year, x.weight, "go")

plt.subplot(2,1,2) # row, column, index
plt.plot(x.year, x.nzhec1, "r^")

plt.suptitle("Sub Plots")
plt.show()

# %%
#2 rows and 2 columns
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6)) #creating a grid of 2 rows, 2 columns and 6x6 figure size
ax[0,0].plot(x.year, x.exp_pw, "go") # The top-left axes
ax[0,1].plot(x.year, x.exp_pw, "bo") # The top-right axes
ax[1,0].plot(x.year, x.exp_pw, "yo") # The bottom-left axes
ax[1,1].plot(x.year, x.exp_pw, "ro") # The bottom-right axes

# %%
#Histogram using `Matplotlib`
plt.title("Histogram")
plt.xlabel("Percentage of Level")
plt.ylabel("Frequency")

plt.hist(x.level)
plt.show()

# %%
# Seaborn
# Seaborn is a Python data visualization library based on Matplotlib.
# It provides a high-level interface for creating attractive graphs, and statistical data visualization.
import seaborn as sns

# %%
# Load iris data
iris = sns.load_dataset("iris")

iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 59            5.2          2.7           3.9          1.4  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 0             5.1          3.5           1.4          0.2      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 103           6.3          2.9           5.6          1.8   virginica
# 21            5.1          3.7           1.5          0.4      setosa
# 107           7.3          2.9           6.3          1.8   virginica
# 27            5.2          3.5           1.5          0.2      setosa
# 111           6.4          2.7           5.3          1.9   virginica
# 14            5.8          4.0           1.2          0.2      setosa

# %%
#Scatter Plot using Seaborn
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
plt.show()

# %%
#Swarm Plot using Seaborn
# Construct swarm plot for sepcies vs petal_length
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Heatmap using Seaborn
# Correlation matrix completely ignores any non-numeric column.
sns.heatmap(iris.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-35-a70130e79b2c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), annot=True)

# %%
#Vertical Bar Charts
plt.bar(x.year, x.exp_pw, color="green")

plt.title("Bar Graph")
plt.xlabel("Year")
plt.ylabel("Expenditure")
plt.show()

# %%
#Horizontal Bar Charts
plt.barh(x.year, x.exp_pw, color="green")
plt.title("Bar Graph")
plt.show()

# %%
#Bar Charts with multiple quantities
divisions = ["A", "B", "C", "D", "E"]
division_avg = [70, 82, 73, 65, 68]
boys_avg = [68, 67, 77, 61, 70]

# Using the NumPy arange function to generate values for index between 0-4.
# Here,stop is 5, start is 0, and step is 1
index = np.arange(5)
width = 0.30

plt.bar(index, division_avg, width, color="green", label="Division Marks")
plt.bar(index+width, boys_avg, width, color="blue", label="Boys Marks")

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
#Stacked Bar Chart
divisions = ["A", "B", "C", "D", "E"]
girls_avg = [72, 97, 69, 69, 66]
boys_avg = [68, 67, 77, 61, 70]

index = np.arange(5)
width = 0.50

plt.bar(index, boys_avg, width, color="green", label="Boys Marks")
plt.bar(index, girls_avg, width, color="blue", label="Girls Marks", bottom=boys_avg)

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
# Pie Chart using Matplotlib
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_share = [20,25,15,10,20]

# Explode the pie chart to emphasize a certain part or some parts( Firm B in this case)
# It is useful because it makes the highlighted portion more visible.
Explode = [0,0.1,0,0,0]

plt.pie(market_share, explode=Explode, labels=firms, autopct='%1.1f%%', startangle=45)

plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend(title="List of Firms")

plt.show()
